# %%
print("hello")
# Out:
# hello

# %% [markdown]
# My name is Hemant, I have plenty of years of ERP (JDE) experience, currently experiencing a setback in my career because of layoff. I am excited to learn the Data Analysis tools and techniques to switch my career to Data Analyst.
